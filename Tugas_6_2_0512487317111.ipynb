# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 11.3 MB 4.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.7 MB 32.5 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# ## Data Understanding
# - Load dataset
# ---

# %% [markdown]
# ## Data Understanding
# - Preview dataset
# ---

# %%
path="customers.csv"
customer = pd.read_csv(path)
customer
# Out:
#        CustomerID Segment Currency
# 0               3     SME      EUR
# 1               5     LAM      EUR
# 2               6     SME      EUR
# 3               7     LAM      EUR
# 4               9     SME      EUR
# ...           ...     ...      ...
# 32456       53307     SME      CZK
# 32457       53309     SME      CZK
# 32458       53311     SME      CZK
# 32459       53313     SME      CZK
# 32460       53314     SME      CZK
#
# [32461 rows x 3 columns]

# %%
path="products.csv"
product = pd.read_csv(path)
product
# Out:
#      ProductID                      Description
# 0            1                     Rucní zadání
# 1            2                            Nafta
# 2            3                          Special
# 3            4                            Super
# 4            5                          Natural
# ..         ...                              ...
# 586        602                              CNG
# 587        603                     Ethanol E-85
# 588        604                Zprostredk.nakupu
# 589        605      Replacement of UTA MultiBox
# 590        630  CCS Carnet Pronájem HW (Manual)
#
# [591 rows x 2 columns]

# %%
path="gasstations.csv"
gas = pd.read_csv(path)
gas
# Out:
#       GasStationID  ChainID Country          Segment
# 0               44       13     CZE  Value for money
# 1               45        6     CZE          Premium
# 2               46       23     CZE            Other
# 3               47       33     CZE          Premium
# 4               48        4     CZE          Premium
# ...            ...      ...     ...              ...
# 5711          5768        3     CZE            Other
# 5712          5769      153     SVK            Other
# 5713          5770        6     CZE          Premium
# 5714          5771        2     CZE           Noname
# 5715          5772       16     CZE            Other
#
# [5716 rows x 4 columns]

# %%
path="transactions_1k.csv"
transaksi = pd.read_csv(path)
transaksi
# Out:
#      TransactionID        Date      Time  CustomerID  CardID  GasStationID  \
# 0                1  2012-08-24  09:41:00       31543  486621          3704
# 1                2  2012-08-24  10:03:00       46707  550134          3704
# 2                3  2012-08-24  10:03:00       46707  550134          3704
# 3                4  2012-08-24  13:53:00        7654  684220           656
# 4                5  2012-08-24  08:49:00       17373  536109           741
# ..             ...         ...       ...         ...     ...           ...
# 995            996  2012-08-26  13:04:00       12021  692529          3750
# 996            997  2012-08-26  11:52:00       15618  602037           438
# 997            998  2012-08-26  12:31:00       47057  533108           438
# 998            999  2012-08-25  07:51:00       22994  602354          3899
# 999           1000  2012-08-25  12:45:00       25986  655214          3899
#
#      ProductID  Amount   Price
# 0            2      28  672.64
# ...

# %% [markdown]
# ## Data Understanding
# - Merge tables
# ---

# %%
hasil=transaksi.merge(customer,on='CustomerID').merge(product,on='ProductID').merge(gas,on='GasStationID')
hasil
# Out:
#      TransactionID        Date      Time  CustomerID  CardID  GasStationID  \
# 0                1  2012-08-24  09:41:00       31543  486621          3704
# 1                2  2012-08-24  10:03:00       46707  550134          3704
# 2                3  2012-08-24  10:03:00       46707  550134          3704
# 3              119  2012-08-24  16:41:00       31543  549271          3591
# 4              118  2012-08-24  06:10:00       47905  751510          3591
# ..             ...         ...       ...         ...     ...           ...
# 995            272  2012-08-24  11:11:00        3014  401151          5134
# 996            414  2012-08-24  11:40:00         272  622621          5261
# 997            887  2012-08-25  09:33:00        3889  519808          4598
# 998            261  2012-08-24  14:41:00        4789  683477          4580
# 999            270  2012-08-24  12:10:00       48664  737416          5128
#
# ...

# %% [markdown]
# ## Data Understanding
# - Preview Data types
# ---

# %%
print(hasil.dtypes)
# Out:
# TransactionID      int64
# Date              object
# Time              object
# CustomerID         int64
# CardID             int64
# GasStationID       int64
# ProductID          int64
# Amount             int64
# Price            float64
# Segment_x         object
# Currency          object
# Description       object
# ChainID            int64
# Country           object
# Segment_y         object
# dtype: object

# %%
path="yearmonth.csv"
jumlahgas = pd.read_csv(path)
jumlahgas
# Out:
#         CustomerID    Date  Consumption
# 0                5  201207       528.30
# 1                5  201302      1598.28
# 2                5  201303      1931.36
# 3                5  201304      1497.14
# 4                6  201203        51.06
# ...            ...     ...          ...
# 383277       52309  201311       138.61
# 383278       52312  201310        78.19
# 383279       52322  201311       125.30
# 383280       52331  201311      3849.73
# 383281       52353  201311      1566.24
#
# [383282 rows x 3 columns]

# %%
df1=pd.DataFrame(hasil, columns=['CustomerID','Price'])
df1.groupby(['CustomerID']) ['Price'].sum()
df1.sort_values(by='Price', ascending=False)
# Out:
#      CustomerID    Price
# 191       13665  5762.49
# 916        7938  3600.84
# 444       39407  3101.98
# 687       21312  3090.45
# 653       26658  3090.39
# ..          ...      ...
# 362       19035     4.74
# 995        3014     3.78
# 975        3014     3.64
# 947        4819     1.76
# 938        4230     1.76
#
# [1000 rows x 2 columns]

# %% [markdown]
# ## Soal-1
# Buatlah table list Top 5 Customers yang memiliki nilai transaksi paling banyak
# ---

# %%
hasil.head()
# Out:
#    TransactionID        Date      Time  CustomerID  CardID  GasStationID  \
# 0              1  2012-08-24  09:41:00       31543  486621          3704
# 1              2  2012-08-24  10:03:00       46707  550134          3704
# 2              3  2012-08-24  10:03:00       46707  550134          3704
# 3            119  2012-08-24  16:41:00       31543  549271          3591
# 4            118  2012-08-24  06:10:00       47905  751510          3591
#
#    ProductID  Amount   Price Segment_x Currency   Description  ChainID  \
# 0          2      28  672.64       KAM      CZK         Nafta        4
# 1          2      18  430.72       KAM      CZK         Nafta        4
# 2         23       1  121.99       KAM      CZK  Provoz.nápl.        4
# 3          2      24  548.40       KAM      CZK         Nafta       26
# 4          2      26  593.11       SME      CZK         Nafta       26
#
#   Country Segment_y
# 0     CZE   Premium
# 1     CZE   Premium
# 2     CZE   Premium
# ...

# %%
df1=pd.DataFrame(hasil, columns=['CustomerID','Price'])
df1.groupby(['CustomerID']) ['Price'].sum()
df1.sort_values(by='Price', ascending=False).head(5)
# Out:
#      CustomerID    Price
# 191       13665  5762.49
# 916        7938  3600.84
# 444       39407  3101.98
# 687       21312  3090.45
# 653       26658  3090.39

# %% [markdown]
# ## Soal-2
# Buatlah list Top 5 Gas stations yang memiliki nilai transaksi paling banyak
# ---

# %%
df1=pd.DataFrame(hasil, columns=['GasStationID','Price'])
df1.groupby(['GasStationID']) ['Price'].sum()
df1.sort_values(by='Price', ascending=False).head(5)
# Out:
#      GasStationID    Price
# 191          3250  5762.49
# 916          3372  3600.84
# 444          2417  3101.98
# 687          3404  3090.45
# 653          3173  3090.39

# %% [markdown]
# ## Soal-3
# Buatlah list Top 5 Jenis produk yang memiliki nilai transaksi paling banyak
# ---

# %%
df1=pd.DataFrame(hasil, columns=['ProductID','Price'])
df1.groupby(['ProductID']) ['Price'].sum()
df1.sort_values(by='Price', ascending=False).head(5)
# Out:
#      ProductID    Price
# 191          2  5762.49
# 916          9  3600.84
# 444          2  3101.98
# 687          2  3090.45
# 653          2  3090.39

# %% [markdown]
# ## Soal-4
# Buatlah deskripsi statistik untuk masing masing hari (23,24,25,26) pada dataset transaction_1k
# ---

# %%
hasil['Amount'].describe().T
# Out:
# count    1000.00000
# mean       19.67800
# std        21.11616
# min         0.00000
# 25%         5.00000
# 50%        19.00000
# 75%        27.00000
# max       264.00000
# Name: Amount, dtype: float64

# %%
hasil.describe()
# Out:
#        TransactionID    CustomerID       CardID  GasStationID    ProductID  \
# count    1000.000000   1000.000000    1000.0000   1000.000000  1000.000000
# mean      500.500000  21975.394000  560899.9670   2290.528000    26.878000
# std       288.819436  14369.180959  165679.4847   1563.275133    79.435755
# min         1.000000     96.000000   26228.0000     48.000000     2.000000
# 25%       250.750000   8507.000000  509899.7500    834.000000     2.000000
# 50%       500.500000  19182.000000  597139.5000   2440.000000     2.000000
# 75%       750.250000  32381.250000  675816.2500   3542.250000     5.000000
# max      1000.000000  49838.000000  775970.0000   5481.000000   352.000000
#
#            Amount        Price      ChainID
# count  1000.00000  1000.000000  1000.000000
# mean     19.67800   425.576160    16.866000
# std      21.11616   470.366199    26.313123
# min       0.00000     1.760000     1.000000
# 25%       5.00000    96.680000     4.000000
# ...

# %% [markdown]
# ## Soal-5
# Carilah waktu terbaik (hari dan jam) dimana paling banyak user gas station melakukan transaksi
# ---

# %% [markdown]
# ## Soal-5
# Dari segi bisnis understanding, tujuan utama dari analisis data customer ini adalah?

# %%
Tujuan analisa ini untuk memberikan gambaran bagaimana perilaku konsumen sehingga bisa mendapatkan keputusan terbaik
