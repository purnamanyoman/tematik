# %%
pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 10.3 MB 4.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.0 MB 38.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.7 MB 40.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.1 MB 60.8 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 11.3 MB 4.6 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Latihan 1: Bitcoin Price
# Kita memiliki daftar harga Bitcoin yang dicatat setiap akhir minggu (Minggu) di 2018 dan
# 2019.  Buat  visualisasi  yang  memungkinkan  Anda  menjawab  pertanyaan:  Tahun  apa,
# 2018 atau 2019, yang cenderung memberikan pengembalian yang lebih baik bagi
# pemegang Bitcoin?

# %%
from datetime import date, timedelta
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
def all_sundays(year):

       dt = date(year, 1, 1)

       dt += timedelta(days = 6 - dt.weekday())  
       while dt.year == year:
          yield dt
          dt += timedelta(days = 7)
   
hari_minggu=[]

for s in all_sundays(2018):
   hari_minggu.append(s.strftime('%m/%d/%Y'))

for s in all_sundays(2019):
   hari_minggu.append(s.strftime('%m/%d/%Y'))


prices = [14292.2, 12858.9, 11467.5, 9241.1, 8559.6, 11073.5, 
9704.3, 11402.3, 
          8762.0, 7874.9, 8547.4, 6938.2, 6905.7, 8004.4, 8923.1, 
9352.4, 
          9853.5, 8459.5, 8245.1, 7361.3, 7646.6, 7515.8, 6505.8, 
6167.3,  
          6398.9, 6765.5, 6254.8, 7408.7, 8234.1, 7014.3, 6231.6, 
6379.1, 
          6734.8, 7189.6, 6184.3, 6519.0, 6729.6, 6603.9, 6596.3, 
6321.7, 
          6572.2, 6494.2, 6386.2, 6427.1, 5621.8, 3920.4, 4196.2, 
3430.4, 
          3228.7, 3964.4, 3706.8, 3785.4, 3597.2, 3677.8, 3570.9, 
3502.5, 
          3661.4, 3616.8, 4120.4, 3823.1, 3944.3, 4006.4, 4002.5, 
4111.8, 
          5046.2, 5051.8, 5290.2, 5265.9, 5830.9, 7190.3, 7262.6, 
8027.4, 
          8545.7, 7901.4, 8812.5, 10721.7, 11906.5, 11268.0, 
11364.9, 10826.7, 
          9492.1, 10815.7, 11314.5, 10218.1, 10131.0, 9594.4, 
10461.1, 10337.3, 
          9993.0, 8208.5, 8127.3, 8304.4, 7957.3, 9230.6, 9300.6, 
8804.5, 
          8497.3, 7324.1, 7546.6, 7510.9, 7080.8, 7156.2, 7321.5, 
7376.8]


x_coords = np.arange(len(hari_minggu))

plt.figure(figsize=(60,30))  #change size
plt.bar(hari_minggu, prices)  #add tick_label
plt.xticks(rotation=90) #rotates text for x-axis labels
plt.xlabel('Hari_minggu')  #add y label
plt.ylabel('Prices')  #add y label
plt.title('Jumlah nilai bitcoin tahun 2018-2019') #add title

plt.show()

# %% [markdown]
# # Latihan 2: Permen
# Kita  memiliki  sekantong  permen.  Terdapat  lima  jenis  permen,  masing-masing  diberi
# nama di bawah ini. Buat diagram yang menunjukkan persentase peluang bahwa kita akan
# mengeluarkan  permen  Snickers  dari  kantong  jika  kita  melakukan  pengambilan  acak.
# Sebutkan peluang memilih permen Snickers

# %%
import matplotlib.pyplot as plt

candy_names = ['Kit Kat', 'Snickers', 'Milky Way', 'Toblerone', 'Twix']
candy_counts = [52, 39, 78, 13, 78]
explode = (0, 0.15, 0, 0, 0)
plt.figure(figsize=(14,7))
plt.pie(
    candy_counts,
    labels= candy_names,
    autopct='%1.1f%%',
    explode=explode,
    shadow='True',
    startangle=90
)
plt.title('Peluang Snickers diambil 1x')
plt.show()
