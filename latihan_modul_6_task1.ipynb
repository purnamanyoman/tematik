# %%
pip install kaggle
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !ls ~/.kaggle
# Out:
# kaggle.json

# %%
# !chmod 600 /root/.kaggle/kaggle.json
# Out:
# chmod: cannot access '/root/.kaggle/kaggle.json': Permission denied

# %%
# !chmod 600 /.kaggle/kaggle.json
# Out:
# chmod: cannot access '/.kaggle/kaggle.json': No such file or directory

# %%
# !chmod 600 /home/jovyan/.kaggle/kaggle.json

# %%
# !kaggle datasets list -s "covid 19 indonesia"
# Out:
# ref                                                         title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# hendratno/covid19-indonesia                                 COVID-19 Indonesia Dataset                          633KB  2021-07-10 14:10:30           6828        117  1.0
# ardisragen/indonesia-coronavirus-cases                      Indonesia-Coronavirus                                10KB  2020-04-15 11:15:41           6582        123  0.9411765
# dionisiusdh/covid19-indonesian-twitter-sentiment            COVID-19 Indonesian Tweets                           10MB  2020-09-25 10:56:03            592         22  1.0
# ...

# %%
# !kaggle datasets download riqulaziz/case-vaccination-covid19-indonesia-dataset
# Out:
# ...
#   0%|                                                | 0.00/268k [00:00<?, ?B/s]
# 100%|████████████████████████████████████████| 268k/268k [00:00<00:00, 11.8MB/s]

# %%
# !kaggle datasets download dionisiusdh/covid19-indonesian-twitter-sentiment
# Out:
# ...
#  67%|█████████████████████████▌            | 7.00M/10.4M [00:00<00:00, 17.8MB/s]
# 100%|██████████████████████████████████████| 10.4M/10.4M [00:00<00:00, 22.8MB/s]

# %%
# !unzip  case-vaccination-covid19-indonesia-dataset.zip
